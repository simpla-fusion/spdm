# %%
import sys
sys.path.append("/home/salmon/workspace/SpDev/SpCommon")
sys.path.append("/home/salmon/workspace/SpDev/SpDB")

from ..util.logger import logger
from spdm.data import Collection
import matplotlib.pyplot as plt
import numpy as np

# %%
# db = Collection("mapping://",
#                     source="mdsplus:///home/salmon/public_data/efit_east",
#                     id_hasher="{shot}",  #
#                     mapping=[
#                         "/home/salmon/workspace/SpDev/SpDB/mapping/EAST/imas/3/static/config.xml",
#                         "/home/salmon/workspace/SpDev/SpDB/mapping/EAST/imas/3/dynamic/config.xml"
#                     ])
db = Collection("EAST:///home/salmon/public_data/~t")

entry = db.open(shot=55555).entry
# Out:
# 2020-11-16 14:02:08,154 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:77:sp_find_module: Can not find module spdm.core.plugins.PluginEAST#EASTCollection
# 2020-11-16 14:02:08,156 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:77:sp_find_module: Can not find module spdm.core.plugins.PluginEast#EastCollection
# 2020-11-16 14:02:08,158 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:77:sp_find_module: Can not find module spdm.core.plugins.PluginEAST#EASTCollection
# 2020-11-16 14:02:08,161 DEBUG [spdm] /home/salmon/workspace/SpDev/SpDB/spdm/util/sp_export.py:77:sp_find_module: Can not find module spdm.core.plugins.Plugineast#eastCollection
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-bae10f11fb7d> in <module>
#       6 #                         "/home/salmon/workspace/SpDev/SpDB/mapping/EAST/imas/3/dynamic/config.xml"
#       7 #                     ])
# ----> 8 db = Collection.Collection("EAST:///home/salmon/public_data/~t")
#       9
#      10 entry = db.open(shot=55555).entry
#
# ~/workspace/SpDev/SpDB/spdm/data/Collection.py in __new__(cls, desc, backend, *args, **kwargs)
#      33             desc = f"{backend}://"
#      34
# ---> 35         n_cls = find_plugin(desc,
#      36                             pattern=f"{__package__}.plugins.Plugin{{name}}",
#      37                             fragment="Collection")
#
# ~/workspace/SpDev/SpDB/spdm/data/Plugin.py in find_plugin(desc, pattern, fragment, *args, **kwargs)
#      81
#      82     if plugin is None:
# ---> 83         raise ModuleNotFoundError(f"Can not find plugin {plugin_name}#{fragment}!  [{desc}]")
#      84     else:
#      85         logger.info(f"Load Plugin: {plugin.__name__}")
#
# ModuleNotFoundError: Can not find plugin EAST#Collection!  [{'authority': '', 'path': '/home/salmon/public_data/~t', 'schema': 'EAST'}]

# %%
# doc = open_xml(["/home/salmon/workspace/SpDev/SpDB/mapping/EAST/imas/3/static"])
# entry = doc.entry

fg=plt.figure()


for coil in entry.pf_active.coil:
    rect=coil.element[0].geometry.rectangle.__value__()
    plt.gca().add_patch(plt.Rectangle((rect.r-rect.width/2.0,rect.z-rect.height/2.0),rect.width,rect.height,fill=False))

plt.gca().add_patch(plt.Polygon(np.array([entry.wall.description_2d.vessel.annular.outline_outer.r.__value__(),    
                                          entry.wall.description_2d.vessel.annular.outline_outer.z.__value__()]).transpose([1,0]),
                                fill=False,closed=True))

plt.gca().add_patch(plt.Polygon(np.array([entry.wall.description_2d.vessel.annular.outline_inner.r.__value__(),    
                                          entry.wall.description_2d.vessel.annular.outline_inner.z.__value__()]).transpose([1,0]),
                                fill=False,closed=True))

plt.gca().add_patch(plt.Polygon(np.array([entry.wall.description_2d[0].limiter.unit[0].outline.r.__value__(),
                                          entry.wall.description_2d[0].limiter.unit[0].outline.z.__value__()]).transpose([1,0]),
                                fill=False,closed=True))

plt.contour(
    entry.equilibrium.time_slice[1].profiles_2d.Mesh.dim1.__value__(),
    entry.equilibrium.time_slice[1].profiles_2d.Mesh.dim2.__value__(),
    entry.equilibrium.time_slice[1].profiles_2d.psi.__value__(),
    levels =30,linewidths=0.4
    )
for time_slice in entry.equilibrium.time_slice[0:10]:
        plt.contour(
            time_slice.profiles_2d[0].Mesh.dim1.__value__(),
            time_slice.profiles_2d[0].Mesh.dim2.__value__(),
            time_slice.profiles_2d[0].psi.__value__(),
            levels=30, linewidths=0.4
        )
plt.axis('scaled')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-9a26e53afc5a> in <module>
#      22
#      23 plt.contour(
# ---> 24     entry.equilibrium.time_slice[1].profiles_2d.Mesh.dim1.__value__()(),
#      25     entry.equilibrium.time_slice[1].profiles_2d.Mesh.dim2.__value__()(),
#      26     entry.equilibrium.time_slice[1].profiles_2d.psi.__value__()(),
#
# ~/workspace/SpDev/SpCommon/spdm/util/LazyProxy.py in __value__()(self)
#     218
#     219     def __value__()(self):
# --> 220         res = self.__real_value__()
#     221         if isinstance(res, collections.abc.Mapping):
#     222             return LazyProxy(res)
#
# ~/workspace/SpDev/SpCommon/spdm/util/LazyProxy.py in __real_value__(self)
#     215         path = object.__getattribute__(self, "__path__")
#     216         handler = object.__getattribute__(self, "__handler__")
# --> 217         return handler.get_value(obj, path)
#     218
#     219     def __value__()(self):
#
# ~/workspace/SpDev/SpDB/spdm/data/Node.py in get_value(self, path, *args, **kwargs)
#      99
#     100     def get_value(self,  path, *args, **kwargs):
# --> 101         return self.get(path, *args, **kwargs)
#     102
#     103     def delete(self, path, *args, **kwargs):
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in get(self, path, is_raw_path, *args, **kwargs)
#      54     def get(self,  path, *args,  is_raw_path=False,  **kwargs):
#      55         if not is_raw_path:
# ---> 56             res = PathTraverser(path).apply(lambda p: self.get(p,  is_raw_path=True, **kwargs))
#      57         else:
#      58             item = self._mapping.get_value(path, *args, **kwargs)
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in apply(self, visitor)
#      50
#      51     def apply(self, visitor):
# ---> 52         res = self.traverse(visitor, [], 0)
#      53         return res[0] if self.is_multiple else res
#      54
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
# ---> 27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#      28         elif isinstance(self._path[idx], slice):
#      29             start = self._path[idx].start or 0
#
# ~/workspace/SpDev/SpCommon/spdm/util/PathTraverser.py in traverse(self, visitor, prev, idx)
#      23         res = None
#      24         if idx >= len(self._path):
# ---> 25             res = visitor(prev)
#      26         elif isinstance(self._path[idx], str) or isinstance(self._path[idx], int):
#      27             res = self.traverse(visitor, prev+[self._path[idx]], idx+1)
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in <lambda>(p)
#      54     def get(self,  path, *args,  is_raw_path=False,  **kwargs):
#      55         if not is_raw_path:
# ---> 56             res = PathTraverser(path).apply(lambda p: self.get(p,  is_raw_path=True, **kwargs))
#      57         else:
#      58             item = self._mapping.get_value(path, *args, **kwargs)
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in get(self, path, is_raw_path, *args, **kwargs)
#      57         else:
#      58             item = self._mapping.get_value(path, *args, **kwargs)
# ---> 59             res = self._fetch(item)
#      60
#      61         return res
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMapping.py in _fetch(self, item, *args, **kwargs)
#      46             if self._holder is None:
#      47                 raise RuntimeError()
# ---> 48             res = self._holder.get(item["{http://fusionyun.org/schema/}data"], *args, **kwargs)
#      49         else:
#      50             res = item
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMDSplus.py in get(self, path, projection, *args, **kwargs)
#      26         if isinstance(path, str) and len(path) > 0:
#      27             try:
# ---> 28                 res = self.holder[tree_name].tdiExecute(path)
#      29             except mds.mdsExceptions.TdiSYNTAX as error:
#      30                 raise SyntaxError(f"MDSplus TDI syntax error [{path}]! {error}")
#
# ~/workspace/SpDev/SpCommon/spdm/util/dict_util.py in __missing__(self, k)
#       6
#       7     def __missing__(self, k):
# ----> 8         v = self._factory(k)
#       9         self.__setitem__(k,  v)
#      10         return v
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMDSplus.py in <lambda>(t, s, m)
#      67         mds_mode = MDSplusDocument.MDS_MODE.get(mode, "NORMAL")
#      68
# ---> 69         self._trees = DefaultDict(lambda t, s=shot, m=mds_mode: open_mdstree(t, s, mode=m))
#      70
#      71         if tree_name is not None:
#
# ~/workspace/SpDev/SpDB/spdm/data/plugins/PluginMDSplus.py in open_mdstree(tree_name, shot, mode)
#      42     try:
#      43         shot = int(shot)
# ---> 44         assert(tree_name is not None)
#      45         logger.debug(f"Opend MDSTree: {tree_name} {shot} mode=\"{mode}\"")
#      46         tree = mds.Tree(tree_name, shot, mode)
#
# AssertionError:

# %%
fg2=plt.figure()

for coil in entry.pf_active.coil:
    print(coil.current.time.__value__().shape)
    plt.plot(coil.current.time.__value__(), coil.current.data.__value__() )
fg2.show()
# Out:
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# (58703,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-00b9089217c9> in <module>
#       2
#       3 for coil in entry.pf_active.coil:
# ----> 4     print(coil.current.time.__value__()().shape)
#       5     plt.plot(coil.current.time.__value__()(), coil.current.data.__value__()() )
#       6 fg2.show()
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
# Out:
# 0
